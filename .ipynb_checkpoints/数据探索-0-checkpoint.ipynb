# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
file_path1='sample.csv'
file_path2='out_of_sample.csv'
train_sample = pd.read_csv(file_path1)
out_of_sample = pd.read_csv(file_path2)
x_src = train_sample.iloc[:, 0:6]
# x_src = x_src.values
x_tar = train_sample.iloc[:, 43:49]
# x_tar = x_tar.values
y_src=train_sample.iloc[:, 42:43]
# # y_src=y_src.values
y_tar=train_sample.iloc[:, 85:86]
# y_tar=y_tar.values
x_tar_o=out_of_sample.iloc[:,0:6]
# x_tar_o=x_tar_o.values
y_tar_o=out_of_sample.iloc[:,42:43]
# y_tar_o=y_tar_o.values
    
#     train_sample=train_sample.values
#     out_of_sample=out_of_sample.values
#     x_src = train_sample[0:57834, 0:6]

#     x_tar = train_sample[0:57834, 7:13]
    
#     y_src=train_sample[0:57834, 6:7]
#     y_tar=train_sample[0:57834, 13:14]
#     x_tar_o=out_of_sample[0:57834, 0:6]
#     y_tar_o=out_of_sample[0:57834, 7:8]

    # example usage

# %%
result = x_src.join(x_tar)
cols=result.columns
data_corr=result.corr().abs()

# %%
plt.subplots(figsize=(12,12))
sns.heatmap(data_corr,annot=True)
sns.heatmap(data_corr,mask=data_corr<1,cbar=False)
plt.show()

# %%
#result=result.join(y_src)

data=result

# %%
threshold = 0
# List of pairs along with correlation above threshold
corr_list = []
size = data.shape[1]

#Search for the highly correlated pairs
for i in range(0,size): #for 'size' features
    for j in range(i+1,size): #avoid repetition
        if (data_corr.iloc[i,j] >= threshold and data_corr.iloc[i,j] < 1) or (data_corr.iloc[i,j] < 0 and data_corr.iloc[i,j] <= -threshold):
            corr_list.append([data_corr.iloc[i,j],i,j]) #store correlation and columns index

#Sort to show higher ones first            
s_corr_list = sorted(corr_list,key=lambda x: -abs(x[0]))

#Print correlations and column names
for v,i,j in s_corr_list:
    print ("%s and %s = %.2f" % (cols[i],cols[j],v))
# Out:
# S2 and S3 = 0.93
# T2 and T3 = 0.93
# S1 and S2 = 0.90
# T5 and T6 = 0.89
# T1 and T2 = 0.88
# S5 and S6 = 0.88
# S1 and S3 = 0.85
# T1 and T3 = 0.84
# S3 and S6 = 0.80
# T3 and T6 = 0.79
# S4 and T4 = 0.74
# S2 and S6 = 0.70
# T4 and T5 = 0.69
# S4 and S5 = 0.69
# T2 and T6 = 0.66
# S1 and S6 = 0.62
# T1 and T6 = 0.61
# T3 and T5 = 0.60
# S5 and T5 = 0.57
# S3 and S5 = 0.56
# S4 and T5 = 0.56
# S1 and T1 = 0.53
# S2 and T1 = 0.52
# S5 and T4 = 0.52
# S3 and T3 = 0.51
# S2 and T2 = 0.51
# S6 and T6 = 0.51
# S5 and T6 = 0.51
# S2 and T3 = 0.49
# S3 and T1 = 0.49
# S3 and T2 = 0.48
# T2 and T5 = 0.47
# S1 and T2 = 0.47
# S2 and S5 = 0.45
# S3 and T6 = 0.45
# S1 and T3 = 0.44
# S6 and T5 = 0.41
# T4 and T6 = 0.41
# S4 and S6 = 0.38
# S6 and T3 = 0.36
# S2 and T6 = 0.36
# S4 and T6 = 0.35
# T1 and T5 = 0.35
# S1 and S5 = 0.30
# S6 and T2 = 0.29
# S1 and T6 = 0.29
# S6 and T1 = 0.29
# S5 and T3 = 0.25
# S3 and T5 = 0.25
# S6 and T4 = 0.23
# S1 and T4 = 0.20
# S5 and T2 = 0.17
# ...

# %%
result=result.join(y_src)
#result=result.join(y_tar)

# %%
result
result=result.sample(frac=0.01,replace=True, random_state=3, axis=0)

# %%
for v,i,j in s_corr_list:
    sns.pairplot(result, size=10, x_vars=cols[i],y_vars=cols[j],hue="S_Y")
    plt.show()
